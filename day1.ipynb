# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sample.png')
print(img.item(0,0,2))
plt.imshow(img)
plt.show()

scale_percent = 500

width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dsize = (width, height)

img = cv2.resize(img, dsize)
cv2.imwrite("sample_larger.png", img)

img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
inv_img = cv2.bitwise_not(img_gray)
#img_gray[thresh == 255] = 0
img_inv = cv2.cvtColor(img_inv,cv2.COLOR_GRAY2BGR)

print(inv_img.item(0,0))
cv2.imwrite("sample_inv.png", inv_img)
# Out:
# 255
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-abe4350e4957> in <module>
#      16 inv_img = cv2.bitwise_not(img_gray)
#      17 #img_gray[thresh == 255] = 0
# ---> 18 img_inv = cv2.cvtColor(img_inv,cv2.COLOR_GRAY2BGR)
#      19
#      20 print(inv_img.item(0,0))
#
# NameError: name 'img_inv' is not defined

# %%
cv2.waitKey(0)
cv2.destroyAllWindows()
